# %% [markdown]
# # Preparing Data

# %%
import pandas as pd
import os
import shutil

# %%
# get covid images from the repo: https://github.com/ieee8023/covid-chestxray-dataset

# choose chest xray image positive covid 19 in metadata file
COVID_FILE_PATH = "C:/Users/ngohuy143/OneDrive/PTIT/Third year/Semester 2/Computer Graphics/Project/covid-chestxray-dataset/metadata.csv"
# get them in the folder "images"
COVID_IMAGES_PATH = "C:/Users/ngohuy143/OneDrive/PTIT/Third year/Semester 2/Computer Graphics/Project/covid-chestxray-dataset/images"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (758, 29)

# %%
df.head(5)
# Out:
#   patientid offset sex   age   finding survival intubated intubation_present  \
# 0         2      0   M  65.0  COVID-19        Y         N                  N
# 1         2      3   M  65.0  COVID-19        Y         N                  N
# 2         2      5   M  65.0  COVID-19        Y         N                  N
# 3         2      6   M  65.0  COVID-19        Y         N                  N
# 4         4      0   F  52.0  COVID-19      NaN         N                  N
#
#   went_icu in_icu     ...                  date  \
# 0        N      N     ...      January 22, 2020
# 1        N      N     ...      January 25, 2020
# 2        N      N     ...      January 27, 2020
# 3        N      N     ...      January 28, 2020
# 4        N      N     ...      January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
COVID_TARGET_DIR = "dataset/covid"
if not os.path.exists(COVID_TARGET_DIR):
    os.mkdir(COVID_TARGET_DIR)

# %%
# moving chosen images to "dataset/covid" folder, they're are front view (PA) images
cnt = 0
for (i,row) in df.iterrows():
    if row["finding"] == "COVID-19" and row["view"] == "PA":  
        filename = row["filename"]
        image_path = os.path.join(COVID_IMAGES_PATH, filename) # get source file
        image_dest_path = os.path.join(COVID_TARGET_DIR, filename) # get destination file
        shutil.copy2(image_path, image_dest_path) # copy from source file to destination file/folder
        print("Moving image", cnt)
        cnt += 1
# Out:
# Moving image 0
# Moving image 1
# Moving image 2
# Moving image 3
# Moving image 4
# Moving image 5
# Moving image 6
# Moving image 7
# Moving image 8
# Moving image 9
# Moving image 10
# Moving image 11
# Moving image 12
# Moving image 13
# Moving image 14
# Moving image 15
# Moving image 16
# Moving image 17
# Moving image 18
# Moving image 19
# Moving image 20
# Moving image 21
# Moving image 22
# Moving image 23
# Moving image 24
# Moving image 25
# Moving image 26
# Moving image 27
# Moving image 28
# Moving image 29
# Moving image 30
# Moving image 31
# Moving image 32
# Moving image 33
# Moving image 34
# Moving image 35
# Moving image 36
# Moving image 37
# Moving image 38
# Moving image 39
# Moving image 40
# Moving image 41
# Moving image 42
# Moving image 43
# Moving image 44
# Moving image 45
# Moving image 46
# Moving image 47
# Moving image 48
# Moving image 49
# Moving image 50
# Moving image 51
# Moving image 52
# Moving image 53
# Moving image 54
# Moving image 55
# ...

# %%
# get normal images from kaggle dataset: https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia
import random
NORMAL_FILE_PATH = "C:/Users/ngohuy143/OneDrive/PTIT/Third year/Semester 2/Computer Graphics/Project/chest_xray/train/NORMAL"

NORMAL_TARGET_DIR = "dataset/normal"
if not os.path.exists(NORMAL_TARGET_DIR):
    os.mkdir(NORMAL_TARGET_DIR)

# %%
image_names = os.listdir(NORMAL_FILE_PATH)

# %%
random.shuffle(image_names)
for i in range(200):
    image_name = image_names[i]
    image_path = os.path.join(NORMAL_FILE_PATH, image_name)
    target_path = os.path.join(NORMAL_TARGET_DIR, image_name)
    shutil.copy2(image_path, target_path)
    print("moving image", i)
# Out:
# moving image 0
# moving image 1
# moving image 2
# moving image 3
# moving image 4
# moving image 5
# moving image 6
# moving image 7
# moving image 8
# moving image 9
# moving image 10
# moving image 11
# moving image 12
# moving image 13
# moving image 14
# moving image 15
# moving image 16
# moving image 17
# moving image 18
# moving image 19
# moving image 20
# moving image 21
# moving image 22
# moving image 23
# moving image 24
# moving image 25
# moving image 26
# moving image 27
# moving image 28
# moving image 29
# moving image 30
# moving image 31
# moving image 32
# moving image 33
# moving image 34
# moving image 35
# moving image 36
# moving image 37
# moving image 38
# moving image 39
# moving image 40
# moving image 41
# moving image 42
# moving image 43
# moving image 44
# moving image 45
# moving image 46
# moving image 47
# moving image 48
# moving image 49
# moving image 50
# moving image 51
# moving image 52
# moving image 53
# moving image 54
# moving image 55
# ...
